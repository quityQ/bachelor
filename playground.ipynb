# %% [markdown]
# Yahoo finance python extension testing

# %%
import yfinance as yf 
dat = yf.Ticker("ADEN")
eu = yf.Market("EUROPE")

# %%
eu.summary

# %% [markdown]
# Scraping tests

# %%
import requests
import pandas as pd
import json

# %%
def get_income_statement(ticker): 
    url = f"https://marketplace.financialmodelingprep.com/public/income-statement/{ticker}?period=annual&limit=4&apikey="
        
    response = requests.get(url).json()

    with open("test.json", "w") as f:
        json.dump(response, f)


get_income_statement("UHR.SW")

# %%
    
companies = pd.read_csv("data\equity_issuers.csv", delimiter=";", encoding = "ISO-8859-1")

# %%
for i, row in companies.iterrows():
    name = row["Company"]
    ticker = row["Symbol"] + ".SW"
    
    
    print("The ticker for " + name + " is " + ticker)

# %% [markdown]
# Data Prep

# %%
import numpy as np
import pandas as pd
import os
import glob

# %%
df = pd.read_json(r"data\balance_sheets\Zug Estates Holding AG_balance_sheet_statement.json")

df

# %%
# creating dataset with all available balance sheets

balance_sheets = pd.DataFrame()

file_list = glob.glob(r".\data\balance_sheets\*.json")

dfs = [] # an empty list to store the data frames
for file in file_list:
    data = pd.read_json(file)
    dfs.append(data)

balance_sheets = pd.concat(dfs, ignore_index=True)

balance_sheets.to_csv("datasets/balance_sheets.csv")

# %%
# creating dataset with all available cash flow statements

cash_flows = pd.DataFrame()

file_list = glob.glob(rf".\data\cash_flow_statements\*.json")

dfs = [] # an empty list to store the data frames
for file in file_list:
    data = pd.read_json(file)
    dfs.append(data)
    
cash_flows = pd.concat(dfs, ignore_index=True)

cash_flows.to_csv("datasets/cash_flows.csv")

# %%
# creating dataset with all available income statements

income_statements = pd.DataFrame()

file_list = glob.glob(rf".\data\income_statements\*.json")

dfs = []
for file in file_list:
    data = pd.read_json(file)
    dfs.append(data)
    
income_statements = pd.concat(dfs, ignore_index=True)

income_statements.to_csv("datasets/income_statements.csv")

# %% [markdown]
# dataset playground

# %%
import pandas as pd

df = pd.read_csv("datasets/balance_sheets.csv")

print(df.head())

# %%
# INFO
print("INFO\n")
print(df.info())
print("*"*50+"\n")

# STAT SUMMARY
print("STAT SUMMARY\n")
print(df.describe())
print("*"*50+"\n")
# MISING VALUES
print("MISSING VALUES\n")
print(df.isnull().sum())
# Out:
# INFO
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 859 entries, 0 to 858
# Data columns (total 55 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   Unnamed: 0                               859 non-null    int64
#  1   date                                     859 non-null    object
#  2   symbol                                   859 non-null    object
#  3   reportedCurrency                         859 non-null    object
#  4   cik                                      857 non-null    float64
#  5   fillingDate                              859 non-null    object
#  6   acceptedDate                             859 non-null    object
#  7   calendarYear                             859 non-null    int64
#  8   period                                   859 non-null    object
#  9   cashAndCashEquivalents                   859 non-null    int64
#  10  shortTermInvestments                     859 non-null    float64
#  11  cashAndShortTermInvestments              859 non-null    int64
#  12  netReceivables                           859 non-null    int64
#  13  inventory                                859 non-null    float64
#  14  otherCurrentAssets                       859 non-null    float64
#  15  totalCurrentAssets                       859 non-null    int64
#  16  propertyPlantEquipmentNet                859 non-null    float64
#  17  goodwill                                 859 non-null    int64
#  18  intangibleAssets                         859 non-null    float64
#  19  goodwillAndIntangibleAssets              859 non-null    float64
#  20  longTermInvestments                      859 non-null    float64
#  21  taxAssets                                859 non-null    int64
#  22  otherNonCurrentAssets                    859 non-null    float64
#  23  totalNonCurrentAssets                    859 non-null    int64
#  24  otherAssets                              859 non-null    float64
#  25  totalAssets                              859 non-null    int64
#  26  accountPayables                          859 non-null    float64
#  27  shortTermDebt                            859 non-null    int64
#  28  taxPayables                              859 non-null    float64
#  29  deferredRevenue                          859 non-null    float64
#  30  otherCurrentLiabilities                  859 non-null    int64
#  31  totalCurrentLiabilities                  859 non-null    int64
#  32  longTermDebt                             859 non-null    int64
#  33  deferredRevenueNonCurrent                859 non-null    float64
#  34  deferredTaxLiabilitiesNonCurrent         859 non-null    int64
#  35  otherNonCurrentLiabilities               859 non-null    int64
#  36  totalNonCurrentLiabilities               859 non-null    int64
#  37  otherLiabilities                         859 non-null    int64
#  38  capitalLeaseObligations                  859 non-null    int64
#  39  totalLiabilities                         859 non-null    int64
#  40  preferredStock                           859 non-null    float64
#  41  commonStock                              859 non-null    int64
#  42  retainedEarnings                         859 non-null    float64
#  43  accumulatedOtherComprehensiveIncomeLoss  859 non-null    float64
#  44  othertotalStockholdersEquity             859 non-null    float64
#  45  totalStockholdersEquity                  859 non-null    int64
#  46  totalEquity                              859 non-null    int64
#  47  totalLiabilitiesAndStockholdersEquity    859 non-null    int64
#  48  minorityInterest                         859 non-null    int64
#  49  totalLiabilitiesAndTotalEquity           859 non-null    int64
#  50  totalInvestments                         859 non-null    float64
#  51  totalDebt                                859 non-null    int64
#  52  netDebt                                  859 non-null    int64
#  53  link                                     859 non-null    object
#  54  finalLink                                859 non-null    object
# dtypes: float64(19), int64(28), object(8)
# memory usage: 369.2+ KB
# None
# **************************************************
#
# STAT SUMMARY
#
#        Unnamed: 0    cik  calendarYear  cashAndCashEquivalents  \
# count  859.000000  857.0    859.000000            8.590000e+02
# mean   429.000000    0.0   2021.823050            3.080300e+09
# std    248.116236    0.0      1.211399            1.872100e+10
# min      0.000000    0.0   2020.000000            0.000000e+00
# 25%    214.500000    0.0   2021.000000            2.999100e+07
# 50%    429.000000    0.0   2022.000000            1.272000e+08
# 75%    643.500000    0.0   2023.000000            1.087522e+09
# max    858.000000    0.0   2024.000000            3.172120e+11
#
#        shortTermInvestments  cashAndShortTermInvestments  netReceivables  \
# count          8.590000e+02                 8.590000e+02    8.590000e+02
# mean           1.595382e+09                 4.032571e+09    7.432635e+08
# std            1.164830e+10                 2.122989e+10    2.617679e+09
# min           -5.000500e+09                -4.457710e+05   -4.717100e+07
# 25%            0.000000e+00                 3.176650e+07    0.000000e+00
# 50%            0.000000e+00                 1.416780e+08    4.300700e+07
# 75%            1.521513e+07                 1.147862e+09    2.591500e+08
# max            1.519100e+11                 3.293770e+11    3.589000e+10
#
#           inventory  otherCurrentAssets  totalCurrentAssets  ...  \
# count  8.590000e+02        8.590000e+02        8.590000e+02  ...
# mean  -3.746111e+09        1.373164e+09        5.707249e+09  ...
# std    5.628109e+10        1.844136e+10        2.245704e+10  ...
# min   -9.741307e+11       -1.134770e+11       -4.457710e+05  ...
# 25%    0.000000e+00        1.442500e+06        1.362000e+08  ...
# 50%    5.900000e+07        1.657100e+07        5.375000e+08  ...
# 75%    3.116030e+08        1.700000e+08        3.176480e+09  ...
# max    1.501900e+10        3.919002e+11        3.574150e+11  ...
#
#        accumulatedOtherComprehensiveIncomeLoss  othertotalStockholdersEquity  \
# count                             8.590000e+02                  8.590000e+02
# mean                              5.957652e+08                 -6.379953e+08
# std                               1.130807e+10                  6.865156e+09
# min                              -2.357000e+10                 -7.103700e+10
# 25%                              -4.765900e+07                 -7.890000e+05
# 50%                               0.000000e+00                  0.000000e+00
# 75%                               7.590237e+07                  0.000000e+00
# max                               2.042241e+11                  1.324795e+11
#
#        totalStockholdersEquity   totalEquity  \
# count             8.590000e+02  8.590000e+02
# mean              3.984833e+09  4.103094e+09
# std               1.303618e+10  1.318239e+10
# min              -1.175000e+10 -9.870000e+09
# 25%               1.737665e+08  1.771685e+08
# 50%               6.177360e+08  6.177360e+08
# 75%               2.404628e+09  2.452436e+09
# max               2.042491e+11  2.042491e+11
#
#        totalLiabilitiesAndStockholdersEquity  minorityInterest  \
# count                           8.590000e+02      8.590000e+02
# mean                            2.525788e+10      1.182609e+08
# std                             1.196600e+11      6.140135e+08
# min                             1.000000e+05     -7.096000e+06
# 25%                             4.014038e+08      0.000000e+00
# 50%                             1.684100e+09      0.000000e+00
# 75%                             1.078174e+10      1.396288e+07
# max                             1.717246e+12      7.773000e+09
#
#        totalLiabilitiesAndTotalEquity  totalInvestments     totalDebt  \
# count                    8.590000e+02      8.590000e+02  8.590000e+02
# mean                     2.525788e+10      7.521600e+09  6.179198e+09
# std                      1.196600e+11      5.775041e+10  4.252085e+10
# min                      1.000000e+05     -2.181600e+07  0.000000e+00
# 25%                      4.014038e+08      2.228500e+06  3.603750e+07
# 50%                      1.684100e+09      2.921400e+07  3.136590e+08
# 75%                      1.078174e+10      2.390460e+08  1.945294e+09
# max                      1.717246e+12      8.314783e+11  7.908055e+11
#
#             netDebt
# count  8.590000e+02
# mean   2.891719e+09
# std    3.037312e+10
# min   -7.917040e+10
# 25%   -2.983350e+07
# 50%    9.243900e+07
# 75%    9.398690e+08
# max    6.178296e+11
#
# [8 rows x 47 columns]
# **************************************************
#
# MISSING VALUES
#
# Unnamed: 0                                 0
# date                                       0
# symbol                                     0
# reportedCurrency                           0
# cik                                        2
# fillingDate                                0
# acceptedDate                               0
# calendarYear                               0
# period                                     0
# cashAndCashEquivalents                     0
# shortTermInvestments                       0
# cashAndShortTermInvestments                0
# netReceivables                             0
# inventory                                  0
# otherCurrentAssets                         0
# totalCurrentAssets                         0
# propertyPlantEquipmentNet                  0
# goodwill                                   0
# intangibleAssets                           0
# goodwillAndIntangibleAssets                0
# longTermInvestments                        0
# taxAssets                                  0
# otherNonCurrentAssets                      0
# totalNonCurrentAssets                      0
# otherAssets                                0
# totalAssets                                0
# accountPayables                            0
# shortTermDebt                              0
# taxPayables                                0
# deferredRevenue                            0
# otherCurrentLiabilities                    0
# totalCurrentLiabilities                    0
# longTermDebt                               0
# deferredRevenueNonCurrent                  0
# deferredTaxLiabilitiesNonCurrent           0
# otherNonCurrentLiabilities                 0
# totalNonCurrentLiabilities                 0
# otherLiabilities                           0
# capitalLeaseObligations                    0
# totalLiabilities                           0
# preferredStock                             0
# commonStock                                0
# retainedEarnings                           0
# accumulatedOtherComprehensiveIncomeLoss    0
# othertotalStockholdersEquity               0
# totalStockholdersEquity                    0
# totalEquity                                0
# totalLiabilitiesAndStockholdersEquity      0
# minorityInterest                           0
# totalLiabilitiesAndTotalEquity             0
# totalInvestments                           0
# totalDebt                                  0
# netDebt                                    0
# link                                       0
# finalLink                                  0
# dtype: int64

# %%
df = df.replace(0, np.nan)

print(df.isnull().sum())
# Out:
# Unnamed: 0                                   1
# date                                         0
# symbol                                       0
# reportedCurrency                             0
# cik                                        859
# fillingDate                                  0
# acceptedDate                                 0
# calendarYear                                 0
# period                                       0
# cashAndCashEquivalents                       2
# shortTermInvestments                       396
# cashAndShortTermInvestments                  0
# netReceivables                             225
# inventory                                  142
# otherCurrentAssets                         153
# totalCurrentAssets                           1
# propertyPlantEquipmentNet                   40
# goodwill                                   409
# intangibleAssets                           113
# goodwillAndIntangibleAssets                 86
# longTermInvestments                        123
# taxAssets                                  196
# otherNonCurrentAssets                       67
# totalNonCurrentAssets                        2
# otherAssets                                599
# totalAssets                                  0
# accountPayables                             93
# shortTermDebt                              237
# taxPayables                                128
# deferredRevenue                            364
# otherCurrentLiabilities                     30
# totalCurrentLiabilities                     15
# longTermDebt                               208
# deferredRevenueNonCurrent                  451
# deferredTaxLiabilitiesNonCurrent           190
# otherNonCurrentLiabilities                  77
# totalNonCurrentLiabilities                  26
# otherLiabilities                           594
# capitalLeaseObligations                    339
# totalLiabilities                             0
# preferredStock                             728
# commonStock                                  7
# retainedEarnings                            25
# accumulatedOtherComprehensiveIncomeLoss    125
# othertotalStockholdersEquity               378
# totalStockholdersEquity                      0
# totalEquity                                  0
# totalLiabilitiesAndStockholdersEquity        0
# minorityInterest                           417
# totalLiabilitiesAndTotalEquity               0
# totalInvestments                            55
# totalDebt                                   52
# netDebt                                      0
# link                                         0
# finalLink                                    0
# dtype: int64

# %%
# Out:
#      Unnamed: 0        date  symbol reportedCurrency  cik fillingDate  \
# 200       200.0  2023-12-31  CIE.SW              CHF  NaN  2023-12-31
# 201       201.0  2022-12-31  CIE.SW              CHF  NaN  2022-12-31
# 202       202.0  2021-12-31  CIE.SW              CHF  NaN  2021-12-31
# 203       203.0  2020-12-31  CIE.SW              CHF  NaN  2020-12-31
#
#             acceptedDate  calendarYear period  cashAndCashEquivalents  ...  \
# 200  2023-12-30 19:00:00          2023     FY                     NaN  ...
# 201  2022-12-30 19:00:00          2022     FY                 10176.0  ...
# 202  2021-12-30 19:00:00          2021     FY                 32708.0  ...
# 203  2020-12-30 19:00:00          2020     FY                     NaN  ...
#
#      totalStockholdersEquity  totalEquity  \
# 200                 -8446809     -8446809
# 201                 -7319565     -7319565
# 202                 -7040306     -7040306
# 203                 -6981314     -6981314
#
#      totalLiabilitiesAndStockholdersEquity  minorityInterest  \
# 200                                3012458               NaN
# 201                                3792545               NaN
# 202                                3914672               NaN
# 203                                3750496               NaN
#
#      totalLiabilitiesAndTotalEquity  totalInvestments   totalDebt   netDebt  \
# 200                         3012458         3010141.0  11332379.0  11332379
# 201                         3792545         3776294.0  11014906.0  11004730
# 202                         3914672         3877280.0  10884237.0  10851529
# 203                         3750496         3750496.0  10534990.0  10534990
#
#                                                   link  \
# 200  https://www.six-group.com/en/products-services...
# 201  https://www.six-group.com/en/products-services...
# 202  https://www.six-group.com/en/products-services...
# 203  https://www.six-group.com/en/products-services...
#
#                                              finalLink
# 200  https://www.six-group.com/en/products-services...
# 201  https://www.six-group.com/en/products-services...
# 202  https://www.six-group.com/en/products-services...
# 203  https://www.six-group.com/en/products-services...
#
# [4 rows x 55 columns]
